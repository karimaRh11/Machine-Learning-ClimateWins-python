# %%
# importing libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
#importing the weather dataframe
path = r'C:\Users\karim\Documents\machine learning'
df_weather = pd.read_csv(os.path.join(path, 'data', 'original Data', 'Dataset-weather-prediction-dataset-processed.csv'))

# %%
df_weather.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
#displaying the dataframe columns
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %% [markdown]
# The DataFrame contains a large number of columns, so the '.info() 'output didn't display all of them by default.

# %%
print(df_weather.columns)
# Out:
# Index(['DATE', 'MONTH', 'BASEL_cloud_cover', 'BASEL_wind_speed',
#        'BASEL_humidity', 'BASEL_pressure', 'BASEL_global_radiation',
#        'BASEL_precipitation', 'BASEL_snow_depth', 'BASEL_sunshine',
#        ...
#        'VALENTIA_cloud_cover', 'VALENTIA_humidity', 'VALENTIA_pressure',
#        'VALENTIA_global_radiation', 'VALENTIA_precipitation',
#        'VALENTIA_snow_depth', 'VALENTIA_sunshine', 'VALENTIA_temp_mean',
#        'VALENTIA_temp_min', 'VALENTIA_temp_max'],
#       dtype='object', length=170)

# %%
# Show only numeric columns
numeric_weather = df_weather.select_dtypes(include='number')

# %%
numeric_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %% [markdown]
# All the dataframe's variables are numerical.

# %%
df_weather.isnull().sum()
# Out:
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
# BASEL_humidity         0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 170, dtype: int64

# %%
time_df = df_weather[['DATE','MONTH']].copy()

# %%
time_df
# Out:
#            DATE  MONTH
# 0      19600101      1
# 1      19600102      1
# 2      19600103      1
# 3      19600104      1
# 4      19600105      1
# ...         ...    ...
# 22945  20221027     10
# 22946  20221028     10
# 22947  20221029     10
# 22948  20221030     10
# 22949  20221031     10
#
# [22950 rows x 2 columns]

# %%
df_weather1=df_weather.drop(['DATE'], axis=1)

# %%
df_weather2=df_weather1.drop(['MONTH'], axis=1)

# %%
df_weather2
# Out:
#        BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0                      7               2.1            0.85          1.0180
# 1                      6               2.1            0.84          1.0180
# 2                      8               2.1            0.90          1.0180
# 3                      3               2.1            0.92          1.0180
# 4                      6               2.1            0.95          1.0180
# ...                  ...               ...             ...             ...
# 22945                  1               2.1            0.79          1.0248
# 22946                  6               2.1            0.77          1.0244
# 22947                  4               2.1            0.76          1.0227
# 22948                  5               2.1            0.80          1.0212
# 22949                  5               2.1            0.84          1.0193
#
# ...

# %%
#scaling the dataset numeric columns
scaler = StandardScaler()
scaled_array = scaler.fit_transform(df_weather2)
scaled_weather = pd.DataFrame(scaled_array, columns=df_weather2.columns)

# %%
# Mean of each column
scaler.mean_
# Out:
# array([-1.97527784e-16, -8.81754123e-16,  6.93514478e-16, -1.69044154e-15,
#        -2.17961693e-16, -6.99706572e-17, -4.95367485e-18, -3.96293988e-17,
#         1.88239644e-16,  4.95367485e-17,  1.28795546e-16,  1.36226058e-16,
#        -2.45206905e-16, -1.23296967e-14, -4.45830736e-17,  3.46757239e-17,
#        -1.63471270e-16,  2.97220491e-17,  1.98146994e-17, -4.95367485e-17,
#         1.13934521e-16,  6.24163031e-16,  4.86840972e-14, -2.53875836e-17,
#         1.03717567e-17,  4.70599110e-17, -1.98146994e-17,  4.45830736e-17,
#         1.18888196e-16,  1.08980847e-16, -1.73378620e-16, -6.53885080e-16,
#         8.77791183e-15,  1.98146994e-16,  1.02788753e-16,  8.42124724e-17,
#        -8.91661472e-17,  1.13934521e-16,  1.78332294e-16, -1.17649778e-16,
#        -2.50160580e-16, -8.11164256e-16,  1.17953190e-14, -4.95367485e-18,
#        -3.09604678e-17,  2.72452117e-17, -1.70901782e-16,  1.48610245e-17,
# ...

# %%
#displaying the scaled weather dataframe
scaled_weather.head()
# Out:
#    BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0           0.660514          -0.02793        0.826097       -0.001949
# 1           0.244897          -0.02793        0.735760       -0.001949
# 2           1.076130          -0.02793        1.277781       -0.001949
# 3          -1.001953          -0.02793        1.458455       -0.001949
# 4           0.244897          -0.02793        1.729466       -0.001949
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_snow_depth  \
# 0               -1.101066            -0.265148         -0.179228
# 1               -1.058108             1.658760         -0.179228
# 2               -1.251420             0.155707         -0.179228
# 3               -0.821838            -0.445514         -0.179228
# 4               -0.746661            -0.164944         -0.179228
#
#    BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  ...  VALENTIA_cloud_cover  \
# ...

# %%
final_df = pd.concat([time_df, scaled_weather], axis=1)

# %%
final_df
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0      19600101      1           0.660514          -0.02793        0.826097
# 1      19600102      1           0.244897          -0.02793        0.735760
# 2      19600103      1           1.076130          -0.02793        1.277781
# 3      19600104      1          -1.001953          -0.02793        1.458455
# 4      19600105      1           0.244897          -0.02793        1.729466
# ...         ...    ...                ...               ...             ...
# 22945  20221027     10          -1.833187          -0.02793        0.284075
# 22946  20221028     10           0.244897          -0.02793        0.103401
# 22947  20221029     10          -0.586336          -0.02793        0.013064
# 22948  20221030     10          -0.170720          -0.02793        0.374412
# 22949  20221031     10          -0.170720          -0.02793        0.735760
#
# ...

# %%
#exportation of the scaled dataframe
final_df.to_csv(os.path.join(path,'data','prepared Data', 'scaled_weather.csv'))
